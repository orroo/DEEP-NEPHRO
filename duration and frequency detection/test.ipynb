# %%
import matplotlib.pyplot as plt 
import pandas as pd

import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import pandas as pd
#       4 import numpy as np
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\__init__.py:159
#     155 from packaging.version import parse as parse_version
#     157 # cbook must import matplotlib only within function
#     158 # definitions, so it is safe to import from it here.
# --> 159 from . import _api, _version, cbook, _docstring, rcsetup
#     160 from matplotlib.cbook import sanitize_sequence
#     161 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\cbook.py:24
#      21 import types
#      22 import weakref
# ---> 24 import numpy as np
#      26 try:
#      27     from numpy.exceptions import VisibleDeprecationWarning  # numpy >= 1.25
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\__init__.py:128
#     125 from . import _distributor_init
#     127 try:
# --> 128     from numpy.__config__ import show as show_config
#     129 except ImportError as e:
#     130     msg = """Error importing numpy: you should not try to import numpy from
#     131     its source directory; please exit the numpy source tree, and relaunch
#     132     your python interpreter from there."""
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#      11 _built_with_meson = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\__init__.py:23
#      20         env_added.append(envkey)
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#      25     import sys
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\multiarray.py:10
#       1 """
#       2 Create the numpy._core.multiarray namespace for backward compatibility.
#       3 In v1.16 the multiarray and umath c-extension modules were merged into
#    (...)
#       6
#       7 """
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#      12 from ._multiarray_umath import *  # noqa: F403
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1190, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# Charger les datasets
df1 = pd.read_csv('FINAL_DATA.csv')  # Dataset 1 (Signes vitaux, contient timestamp)

# %%
df1.duplicated().sum()
# Out:
# np.int64(44449)

# %%
df1[df1['pid'] == 16956543].keyindate.unique()
# Out:
# array(['2016-06-08 08:00:00', '2015-06-10 08:00:00',
#        '2016-01-20 08:00:00', '2016-08-31 08:00:00',
#        '2016-07-18 08:00:00', '2016-03-18 08:00:00',
#        '2015-07-22 08:00:00', '2017-07-26 08:00:00',
#        '2016-06-24 08:00:00', '2015-10-21 08:00:00',
#        '2015-10-19 08:00:00', '2018-03-07 08:00:00',
#        '2016-04-25 08:00:00', '2018-01-19 08:00:00',
#        '2016-04-27 08:00:00', '2016-02-26 08:00:00',
#        '2018-03-05 08:00:00', '2018-04-06 08:00:00',
#        '2018-01-05 08:00:00', '2015-11-25 08:00:00',
#        '2018-03-02 08:00:00', '2016-08-15 08:00:00',
#        '2016-09-02 08:00:00', '2018-04-04 08:00:00',
#        '2016-10-28 08:00:00', '2018-01-22 08:00:00',
#        '2017-08-16 08:00:00', '2015-05-06 08:00:00',
#        '2016-07-20 08:00:00', '2018-05-11 08:00:00',
#        '2014-09-05 08:00:00', '2015-09-02 08:00:00',
#        '2016-12-23 08:00:00', '2018-05-14 08:00:00',
#        '2015-01-19 08:00:00', '2014-09-03 08:00:00'], dtype=object)

# %%
f = pd.read_csv('../frequency.csv')  # Dataset 1 (Signes vitaux, contient timestamp)

# %%
f
# Out:
#           pid  avg_weekly_sessions
# 0      102117             2.693548
# 1     1025914             2.643243
# 2    10267491             1.666667
# 3    10270116             1.000000
# 4    10434576             2.000000
# ..        ...                  ...
# 840   9842114             2.000000
# 841   9906309             1.800000
# 842   9906636             1.333333
# 843    993387             2.000000
# 844   9982427             2.000000
#
# [845 rows x 2 columns]

# %%
df1
# Out:
#             pid             datatime  sbp  dbp  temperature  conductivity  \
# 0      33519362  2016-02-03 00:04:50  140   55         36.0          14.4
# 1      33519362  2016-02-03 00:04:50  140   55         36.0          14.4
# 2      33519362  2016-02-03 00:04:50  140   55         36.0          14.4
# 3      16956543  2016-06-08 00:17:18  160   81         36.0          14.0
# 4      16956543  2016-06-08 00:17:18  160   81         36.0          14.0
# ...         ...                  ...  ...  ...          ...           ...
# 92892  37167665  2014-12-31 23:59:59  143   74         36.5          14.1
# 92893  37167665  2014-12-31 23:59:59  143   74         36.5          14.1
# 92894   9464887  2018-02-20 23:59:59  123   55         36.5          14.0
# 92895   9464887  2018-02-20 23:59:59  123   55         36.5          14.0
# 92896  20868771  2017-02-02 23:59:59  138   63         36.0          14.1
#
#           uf  blood_flow  gender  birthday  ... technique  gain  \
# 0      1.100         200       1      1961  ...       1.0   4.6
# 1      1.100         200       1      1961  ...       1.0   4.6
# 2      1.100         200       1      1961  ...       1.0   4.6
# 3      1.119         219       1      1958  ...       1.0   2.1
# 4      1.119         219       1      1958  ...       1.0   2.1
# ...      ...         ...     ...       ...  ...       ...   ...
# 92892  0.000         198       1      1960  ...       1.0  -0.6
# 92893  0.000         198       1      1960  ...       1.0  -0.6
# 92894  0.000         251       1      1939  ...       1.0   1.8
# 92895  0.000         251       1      1939  ...       1.0   1.8
# 92896  0.100           0       1      1951  ...       1.0   4.0
#
#       bath_temperature replacement_Volume    kt  Bath_Flow  \
# 0                 36.5              23.95  63.2      812.0
# 1                 36.5              23.95  63.2      812.0
# 2                 36.5              23.95  63.2      812.0
# 3                 35.5              26.48  47.1      221.0
# 4                 35.5              26.48  47.1      221.0
# ...                ...                ...   ...        ...
# 92892             35.5              64.70  60.3        0.0
# 92893             35.5              64.70  60.3        0.0
# 92894             36.0              20.12  47.3        0.0
# 92895             36.0              20.12  47.3        0.0
# 92896              0.0               3.15  70.2      784.0
#
#        bicarbonate_conductivity  arterial_Pressure  Venous_Pressure  \
# 0                           0.0             -150.0            145.0
# 1                           0.0             -150.0            145.0
# 2                           0.0             -150.0            145.0
# 3                           0.0             -180.0             60.0
# 4                           0.0             -180.0             60.0
# ...                         ...                ...              ...
# 92892                       0.0             -235.0            150.0
# 92893                       0.0             -235.0            150.0
# 92894                       0.0              -45.0             15.0
# 92895                       0.0              -45.0             15.0
# 92896                       0.0             -255.0            225.0
#
#        transmembrane_Pressure
# 0                       165.0
# 1                       165.0
# 2                       165.0
# 3                       130.0
# 4                       130.0
# ...                       ...
# 92892                   105.0
# 92893                   105.0
# 92894                   140.0
# 92895                   140.0
# 92896                   140.0
#
# [92897 rows x 37 columns]

# %%
df1 = df1.merge(f,on='pid',how='right')

# %%
df1
# Out:
#            pid             datatime    sbp   dbp  temperature  conductivity  \
# 0       102117  2017-10-21 19:47:48  138.0  81.0         36.0          13.6
# 1       102117  2017-10-21 19:48:34  138.0  81.0         36.0          14.0
# 2       102117  2014-09-11 19:48:51  114.0  62.0         36.0          14.2
# 3       102117  2014-09-11 19:48:51  114.0  62.0         36.0          14.2
# 4       102117  2014-09-11 19:48:51  114.0  62.0         36.0          14.2
# ...        ...                  ...    ...   ...          ...           ...
# 93235  9982427  2014-01-16 22:59:45  152.0  54.0         36.5          14.1
# 93236  9982427  2014-01-16 23:00:56  152.0  54.0         36.5          14.2
# 93237  9982427  2014-01-16 23:01:14  152.0  54.0         36.5          14.2
# 93238  9982427  2014-01-16 23:01:19  152.0  54.0         36.5          14.2
# 93239  9982427  2014-01-16 23:01:24  152.0  54.0         36.5          14.1
#
#          uf  blood_flow  gender  birthday  ... gain  bath_temperature  \
# 0      0.00       150.0     2.0    1931.0  ...  0.2               0.0
# 1      0.50       150.0     2.0    1931.0  ...  0.2               0.0
# 2      0.73       150.0     2.0    1931.0  ... -0.2              35.5
# 3      0.73       150.0     2.0    1931.0  ... -0.2              35.5
# 4      0.73       150.0     2.0    1931.0  ... -0.2              35.5
# ...     ...         ...     ...       ...  ...  ...               ...
# 93235  0.30       220.0     2.0    1940.0  ...  0.4               0.0
# 93236  0.30         0.0     2.0    1940.0  ...  0.4               0.0
# 93237  0.30       220.0     2.0    1940.0  ...  0.4               0.0
# 93238  0.30         0.0     2.0    1940.0  ...  0.4               0.0
# 93239  0.30       220.0     2.0    1940.0  ...  0.4               0.0
#
#       replacement_Volume    kt Bath_Flow  bicarbonate_conductivity  \
# 0                  24.84  50.2     807.0                       0.0
# 1                  24.84  50.2     807.0                       0.0
# 2                  29.45  44.2     492.0                       0.0
# 3                  29.45  44.2     492.0                       0.0
# 4                  29.45  44.2     492.0                       0.0
# ...                  ...   ...       ...                       ...
# 93235              26.82  52.2     364.0                       0.0
# 93236              26.82  52.2     364.0                       0.0
# 93237              26.82  52.2     364.0                       0.0
# 93238              26.82  52.2     364.0                       0.0
# 93239              26.82  52.2     364.0                       0.0
#
#        arterial_Pressure  Venous_Pressure  transmembrane_Pressure  \
# 0                 -240.0            195.0                   175.0
# 1                 -240.0            195.0                   175.0
# 2                 -220.0            185.0                   165.0
# 3                 -220.0            185.0                   165.0
# 4                 -220.0            185.0                   165.0
# ...                  ...              ...                     ...
# 93235             -170.0            110.0                   155.0
# 93236             -170.0            110.0                   155.0
# 93237             -170.0            110.0                   155.0
# 93238             -170.0            110.0                   155.0
# 93239             -170.0            110.0                   155.0
#
#        avg_weekly_sessions
# 0                 2.693548
# 1                 2.693548
# 2                 2.693548
# 3                 2.693548
# 4                 2.693548
# ...                    ...
# 93235             2.000000
# 93236             2.000000
# 93237             2.000000
# 93238             2.000000
# 93239             2.000000
#
# [93240 rows x 38 columns]

# %%
df1=df1.drop_duplicates()

# %%
df1.drop(columns=['temperature.1'], inplace=True)
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\3640837746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns=['temperature.1'], inplace=True)

# %%
df1.columns
# Out:
# Index(['pid', 'datatime', 'sbp', 'dbp', 'temperature', 'conductivity', 'uf',
#        'blood_flow', 'gender', 'birthday', 'first_dialysis', 'DM', 'keyindate',
#        'dialysisstart', 'dialysisend', 'weightstart', 'weightend', 'dryweight',
#        'pulse', 'respiratory_rate', 'blood_oxygen_lvl', 'glucose_lvl',
#        'hypotension', 'age', 'dialyzer', 'bath', 'technique', 'gain',
#        'bath_temperature', 'replacement_Volume', 'kt', 'Bath_Flow',
#        'bicarbonate_conductivity', 'arterial_Pressure', 'Venous_Pressure',
#        'transmembrane_Pressure', 'avg_weekly_sessions'],
#       dtype='object')

# %%
df1.avg_weekly_sessions.describe()
# Out:
# count    48791.000000
# mean         2.544583
# std          0.366033
# min          1.000000
# 25%          2.541485
# 50%          2.669231
# 75%          2.743590
# max          3.000000
# Name: avg_weekly_sessions, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48791 entries, 0 to 93239
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pid                       48791 non-null  int64
#  1   datatime                  48448 non-null  object
#  2   sbp                       48448 non-null  float64
#  3   dbp                       48448 non-null  float64
#  4   temperature               48448 non-null  float64
#  5   conductivity              48448 non-null  float64
#  6   uf                        48448 non-null  float64
#  7   blood_flow                48448 non-null  float64
#  8   gender                    48448 non-null  float64
#  9   birthday                  48448 non-null  float64
#  10  first_dialysis            48448 non-null  object
#  11  DM                        48448 non-null  float64
#  12  keyindate                 48448 non-null  object
#  13  dialysisstart             48448 non-null  object
#  14  dialysisend               48448 non-null  object
#  15  weightstart               48448 non-null  float64
#  16  weightend                 48448 non-null  float64
#  17  dryweight                 48448 non-null  float64
#  18  pulse                     48448 non-null  float64
#  19  respiratory_rate          48448 non-null  float64
#  20  blood_oxygen_lvl          48448 non-null  float64
#  21  glucose_lvl               48448 non-null  float64
#  22  hypotension               48448 non-null  object
#  23  age                       48448 non-null  float64
#  24  dialyzer                  48448 non-null  float64
#  25  bath                      48448 non-null  float64
#  26  technique                 48448 non-null  float64
#  27  gain                      48448 non-null  float64
#  28  bath_temperature          48448 non-null  float64
#  29  replacement_Volume        48448 non-null  float64
#  30  kt                        48448 non-null  float64
#  31  Bath_Flow                 48448 non-null  float64
#  32  bicarbonate_conductivity  48448 non-null  float64
#  33  arterial_Pressure         48448 non-null  float64
#  34  Venous_Pressure           48448 non-null  float64
#  35  transmembrane_Pressure    48448 non-null  float64
#  36  avg_weekly_sessions       48791 non-null  float64
# dtypes: float64(30), int64(1), object(6)
# memory usage: 14.1+ MB

# %%
plt.scatter(df1['pid'], df1['avg_weekly_sessions'])

# Adding Title to the Plot
plt.title("Scatter Plot")

# Setting the X and Y labels
plt.xlabel('date')
plt.ylabel('value')

plt.show()

# %%
df1.hypotension.unique()
# Out:
# array(['NO', 'SI', nan], dtype=object)

# %%
df1.isnull().sum()
# Out:
# pid                           0
# datatime                    343
# sbp                         343
# dbp                         343
# temperature                 343
# conductivity                343
# uf                          343
# blood_flow                  343
# gender                      343
# birthday                    343
# first_dialysis              343
# DM                          343
# keyindate                   343
# dialysisstart               343
# dialysisend                 343
# weightstart                 343
# weightend                   343
# dryweight                   343
# pulse                       343
# respiratory_rate            343
# blood_oxygen_lvl            343
# glucose_lvl                 343
# hypotension                 343
# age                         343
# dialyzer                    343
# bath                        343
# technique                   343
# gain                        343
# bath_temperature            343
# replacement_Volume          343
# kt                          343
# Bath_Flow                   343
# bicarbonate_conductivity    343
# arterial_Pressure           343
# Venous_Pressure             343
# transmembrane_Pressure      343
# avg_weekly_sessions           0
# dtype: int64

# %%
df1.dropna(inplace=True)
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\3614008390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace=True)

# %%
df1.dtypes
# Out:
# pid                           int64
# datatime                     object
# sbp                         float64
# dbp                         float64
# temperature                 float64
# conductivity                float64
# uf                          float64
# blood_flow                  float64
# gender                      float64
# birthday                    float64
# first_dialysis               object
# DM                          float64
# keyindate                    object
# dialysisstart                object
# dialysisend                  object
# weightstart                 float64
# weightend                   float64
# dryweight                   float64
# pulse                       float64
# respiratory_rate            float64
# blood_oxygen_lvl            float64
# glucose_lvl                 float64
# hypotension                  object
# age                         float64
# dialyzer                    float64
# bath                        float64
# technique                   float64
# gain                        float64
# bath_temperature            float64
# replacement_Volume          float64
# kt                          float64
# Bath_Flow                   float64
# bicarbonate_conductivity    float64
# arterial_Pressure           float64
# Venous_Pressure             float64
# transmembrane_Pressure      float64
# avg_weekly_sessions         float64
# dtype: object

# %%
df1.dialysisend
# Out:
# 0        15:55
# 1        15:55
# 2        15:54
# 5        15:58
# 6        15:54
#          ...
# 93235    16:26
# 93236    16:26
# 93237    16:26
# 93238    16:26
# 93239    16:26
# Name: dialysisend, Length: 48448, dtype: object

# %%
df1["De_hour"] = pd.to_datetime( df1.dialysisend).dt.hour
df1["De_minutes"] = pd.to_datetime( df1.dialysisend).dt.minute
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\4263929332.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1["De_hour"] = pd.to_datetime( df1.dialysisend).dt.hour
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\4263929332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["De_hour"] = pd.to_datetime( df1.dialysisend).dt.hour
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\4263929332.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1["De_minutes"] = pd.to_datetime( df1.dialysisend).dt.minute
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\4263929332.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["De_minutes"] = pd.to_datetime( df1.dialysisend).dt.minute

# %%
df1["Ds_hour"] = pd.to_datetime( df1.dialysisstart).dt.hour
df1["Ds_minutes"] = pd.to_datetime( df1.dialysisstart).dt.minute
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\2443749480.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1["Ds_hour"] = pd.to_datetime( df1.dialysisstart).dt.hour
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\2443749480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Ds_hour"] = pd.to_datetime( df1.dialysisstart).dt.hour
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\2443749480.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1["Ds_minutes"] = pd.to_datetime( df1.dialysisstart).dt.minute
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\2443749480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Ds_minutes"] = pd.to_datetime( df1.dialysisstart).dt.minute

# %%
df1["session_year"] =  pd.to_datetime( df1.keyindate).dt.year
df1["session_month"] = pd.to_datetime( df1.keyindate).dt.month
df1["session_dayofweek"] = pd.to_datetime( df1.keyindate).dt.dayofweek
df1["session_is_weekend"] = df1["session_dayofweek"].apply(lambda x: 1 if x >= 5 else 0)
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\101800460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["session_year"] =  pd.to_datetime( df1.keyindate).dt.year
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\101800460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["session_month"] = pd.to_datetime( df1.keyindate).dt.month
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\101800460.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["session_dayofweek"] = pd.to_datetime( df1.keyindate).dt.dayofweek
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\101800460.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["session_is_weekend"] = df1["session_dayofweek"].apply(lambda x: 1 if x >= 5 else 0)

# %%
df1["fd_year"] =  pd.to_datetime( df1.first_dialysis).dt.year
df1["fd_month"] = pd.to_datetime( df1.first_dialysis).dt.month
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\1038825848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["fd_year"] =  pd.to_datetime( df1.first_dialysis).dt.year
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\1038825848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["fd_month"] = pd.to_datetime( df1.first_dialysis).dt.month

# %%
df1["year"] =  pd.to_datetime( df1.datatime).dt.year
df1["month"] = pd.to_datetime( df1.datatime).dt.month
df1["dayofweek"] = pd.to_datetime( df1.datatime).dt.dayofweek
df1["is_weekend"] = df1["dayofweek"].apply(lambda x: 1 if x >= 5 else 0)
df1["hour"] = pd.to_datetime( df1.datatime).dt.hour
df1["minutes"] = pd.to_datetime( df1.datatime).dt.minute
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\803205007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["year"] =  pd.to_datetime( df1.datatime).dt.year
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\803205007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["month"] = pd.to_datetime( df1.datatime).dt.month
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\803205007.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["dayofweek"] = pd.to_datetime( df1.datatime).dt.dayofweek
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\803205007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["is_weekend"] = df1["dayofweek"].apply(lambda x: 1 if x >= 5 else 0)
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\803205007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["hour"] = pd.to_datetime( df1.datatime).dt.hour
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\803205007.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["minutes"] = pd.to_datetime( df1.datatime).dt.minute

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal = OrdinalEncoder(categories=[['SI', 'NO']])
df1.hypotension = ordinal.fit_transform(df1.hypotension.values.reshape(-1, 1))
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_10320\2368016868.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.hypotension = ordinal.fit_transform(df1.hypotension.values.reshape(-1, 1))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
Y = df1['avg_weekly_sessions']
X= df1.drop(columns=['avg_weekly_sessions','pid','datatime','keyindate','first_dialysis','dialysisstart','dialysisend'])

# %%
Y.unique()
# Out:
# array([2.69354839, 2.64324324, 1.66666667, 2.        , 1.16666667,
#        2.42654028, 2.68871595, 1.75      , 2.81992337, 1.        ,
#        1.5       , 2.79007634, 2.5256917 , 2.62109375, 2.64655172,
#        1.09090909, 2.71502591, 1.8       , 2.61068702, 1.1       ,
#        2.6744186 , 2.66666667, 2.25842697, 2.52752294, 2.775     ,
#        2.78927203, 2.5959596 , 2.45522388, 2.42553191, 1.33333333,
#        2.75720165, 2.64489796, 2.69753086, 2.75757576, 2.515625  ,
#        2.76136364, 2.80152672, 2.82681564, 2.73563218, 1.6952381 ,
#        2.59589041, 1.92307692, 2.69587629, 2.70281124, 1.97058824,
#        2.71859296, 1.2       , 2.80988593, 2.35526316, 2.68103448,
#        2.67058824, 2.63461538, 2.396     , 2.5       , 2.32142857,
#        2.77394636, 1.05882353, 2.27559055, 3.        , 2.69318182,
#        2.77037037, 2.77844311, 2.33333333, 2.74678112, 2.4469697 ,
#        2.45238095, 2.3030303 , 1.02547771, 2.68487395, 2.60465116,
#        1.25      , 2.4829932 , 2.66055046, 2.44680851, 2.59689922,
#        2.44897959, 1.875     , 2.44444444, 2.67114094, 2.20588235,
#        1.92376682, 2.68992248, 2.68582375, 2.68907563, 2.79310345,
#        1.9       , 1.28571429, 1.61111111, 2.58461538, 2.63984674,
#        1.96982759, 2.71264368, 2.63309353, 1.77777778, 2.64285714,
#        2.45106383, 2.45652174, 2.31481481, 1.74025974, 1.54545455,
#        2.56692913, 2.56809339, 2.125     , 2.61977186, 2.7       ,
#        2.2       , 2.25      , 2.74358974, 1.79166667, 2.816     ,
#        2.52      , 2.54148472, 1.12068966, 2.7716895 , 1.45454545,
#        2.640625  , 1.4       , 2.79081633, 2.53571429, 1.59259259,
#        1.625     , 1.26086957, 2.34375   , 2.58139535, 1.51428571,
#        2.4       , 2.69346734, 1.80566802, 1.96666667, 2.68      ,
#        1.91666667, 2.63636364, 1.17391304, 2.56923077, 2.70068027,
#        2.4822695 , 2.18518519, 2.64573991, 2.75      , 2.6641791 ,
#        2.73180077, 2.74476987, 2.28169014, 2.64478764, 2.74545455,
#        1.47457627, 2.41295547, 2.55813953, 1.82165605, 2.67692308,
#        2.80676329, 2.6       , 1.14285714, 2.82442748, 2.09433962,
#        2.70253165, 2.79166667, 1.6       , 2.735     , 2.72413793,
#        1.75675676, 2.67567568, 1.3       , 2.5625    , 2.43939394,
#        2.67924528, 1.63333333, 2.57587549, 2.70075758, 2.76428571,
#        2.80425532, 2.38888889, 2.55862069, 2.73076923, 1.50299401,
#        1.69230769, 2.82312925, 2.69019608, 2.58474576, 1.57142857,
#        1.89211618, 1.64516129, 2.55421687, 2.63424125, 2.76978417,
#        1.26666667, 2.69680851, 2.78378378, 2.66923077, 2.46491228,
#        2.62162162, 2.25806452, 2.64102564, 2.84137931, 2.47104247,
#        2.78703704, 2.58      , 2.79220779, 2.8071066 , 2.805     ,
#        2.76833977, 2.55238095, 2.77906977, 2.64583333, 1.85714286,
#        2.56451613, 2.82421875, 2.77327935, 2.51445087, 2.18875502,
#        2.64092664, 2.63350785, 1.71428571, 2.69902913, 1.14814815,
#        1.06060606, 1.05555556, 2.56521739, 2.77637131, 2.23188406,
#        2.08823529, 2.87845304, 2.69078947, 2.70656371, 2.73631841,
#        2.84745763, 2.60098522, 1.83333333, 2.76470588, 2.375     ,
#        2.42635659, 2.91823899, 2.71541502, 2.6221374 , 1.22222222,
#        1.08695652, 2.63565891, 2.8540146 , 1.125     , 1.65217391,
#        2.63414634, 2.6023166 , 2.421875  , 2.75722543, 2.28205128,
#        2.71428571, 2.54814815, 2.61788618, 1.07142857, 2.55      ,
#        1.86666667, 2.68461538, 2.68846154, 1.375     , 2.64039409,
#        2.34134615, 2.71764706, 1.64383562, 1.736     , 2.45833333,
#        1.11627907, 2.67181467, 2.46376812, 2.52173913, 2.6978022 ,
#        2.65991903, 2.65957447, 2.65517241, 2.6988417 , 2.62719298,
#        2.81060606, 1.35672515])

# %%
X.shape
# Out:
# (48448, 46)

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingRegressor

# Fit an initial logistic regression model
model = GradientBoostingRegressor()
selector = RFE(estimator=model, n_features_to_select=25)
X_selected = selector.fit_transform(X, Y)
print(selector.support_)  # Boolean mask of selected features
print(selector.ranking_)  # Ranking of features (1 is best)
# Out:
# [ True  True  True False  True  True  True  True  True  True  True  True
#  False False False False False  True False False False False False False
#   True  True False False  True False  True  True  True  True  True False
#   True False  True  True  True False False False  True False]
# [ 1  1  1  6  1  1  1  1  1  1  1  1 22  4  9 20 21  1 19  8 13  2 16  5
#   1  1 15  3  1 18  1  1  1  1  1 17  1 14  1  1  1 10  7 11  1 12]

# %%
n=len(X.columns)
names=X.columns
print(names)

X.head()
for i in range(0,n):
    if ~selector.support_[i]:
        X= X.drop(names[i] , axis=1)
# Out:
# Index(['sbp', 'dbp', 'temperature', 'conductivity', 'uf', 'blood_flow',
#        'gender', 'birthday', 'DM', 'weightstart', 'weightend', 'dryweight',
#        'pulse', 'respiratory_rate', 'blood_oxygen_lvl', 'glucose_lvl',
#        'hypotension', 'age', 'dialyzer', 'bath', 'technique', 'gain',
#        'bath_temperature', 'replacement_Volume', 'kt', 'Bath_Flow',
#        'bicarbonate_conductivity', 'arterial_Pressure', 'Venous_Pressure',
#        'transmembrane_Pressure', 'De_hour', 'De_minutes', 'Ds_hour',
#        'Ds_minutes', 'session_year', 'session_month', 'session_dayofweek',
#        'session_is_weekend', 'fd_year', 'fd_month', 'year', 'month',
#        'dayofweek', 'is_weekend', 'hour', 'minutes'],
#       dtype='object')

# %%
X.shape
# Out:
# (48448, 25)

# %%
X.columns
# Out:
# Index(['sbp', 'dbp', 'temperature', 'uf', 'blood_flow', 'gender', 'birthday',
#        'DM', 'weightstart', 'weightend', 'dryweight', 'age', 'kt', 'Bath_Flow',
#        'Venous_Pressure', 'De_hour', 'De_minutes', 'Ds_hour', 'Ds_minutes',
#        'session_year', 'session_dayofweek', 'fd_year', 'fd_month', 'year',
#        'hour'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposed = seasonal_decompose(df1["avg_weekly_sessions"], model="additive", period=12)
decomposed.plot()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler



scaler = MinMaxScaler()



scaled_data2 = scaler.fit_transform(X_train)



scaled_df1 = pd.DataFrame(scaled_data2, columns=X.columns)


scaled_df1
# Out:
#             sbp       dbp  temperature        uf  blood_flow  gender  \
# 0      0.424242  0.350649     0.400000  0.280000       0.625     0.0
# 1      0.431818  0.285714     0.333333  0.140000       0.625     1.0
# 2      0.462121  0.233766     0.222222  0.033333       1.000     0.0
# 3      0.424242  0.272727     0.333333  0.087333       0.625     0.0
# 4      0.439394  0.259740     0.333333  0.249333       0.575     1.0
# ...         ...       ...          ...       ...         ...     ...
# 38753  0.386364  0.285714     0.155556  0.276667       0.625     1.0
# 38754  0.893939  0.766234     0.111111  0.433333       0.000     0.0
# 38755  0.515152  0.415584     0.444444  0.250000       0.620     0.0
# 38756  0.454545  0.597403     0.333333  0.200000       0.575     1.0
# 38757  0.613636  0.545455     0.444444  0.143333       0.425     1.0
#
#        birthday   DM  weightstart  weightend  ...   De_hour  De_minutes  \
# 0      0.631579  0.0     0.290242   0.288557  ...  0.333333    0.067797
# 1      0.210526  0.0     0.215328   0.231841  ...  0.666667    0.406780
# 2      0.184211  1.0     0.222051   0.235423  ...  0.600000    0.796610
# 3      0.236842  0.0     0.190357   0.212935  ...  0.666667    0.271186
# 4      0.486842  1.0     0.441990   0.452239  ...  0.666667    0.000000
# ...         ...  ...          ...        ...  ...       ...         ...
# 38753  0.565789  1.0     0.489243   0.498507  ...  0.333333    0.355932
# 38754  0.592105  0.0     0.500576   0.496517  ...  0.333333    0.271186
# 38755  0.105263  1.0     0.353630   0.359204  ...  0.666667    0.694915
# 38756  0.407895  1.0     0.332501   0.340299  ...  0.600000    0.881356
# 38757  0.434211  0.0     0.203803   0.214925  ...  0.666667    0.000000
#
#         Ds_hour  Ds_minutes  session_year  session_dayofweek   fd_year  \
# 0      0.090909    0.067797           0.4                0.6  0.500000
# 1      0.545455    0.406780           0.8                0.4  0.500000
# 2      0.454545    0.796610           0.4                1.0  0.884615
# 3      0.545455    0.271186           0.4                0.4  0.500000
# 4      0.545455    0.000000           0.6                0.2  0.730769
# ...         ...         ...           ...                ...       ...
# 38753  0.090909    0.355932           0.4                0.8  0.923077
# 38754  0.090909    0.220339           0.8                0.8  0.500000
# 38755  0.545455    0.779661           0.2                1.0  0.923077
# 38756  0.454545    0.881356           0.2                0.2  0.576923
# 38757  0.545455    0.000000           0.2                0.4  0.538462
#
#        fd_month  year      hour
# 0      1.000000   0.4  0.782609
# 1      1.000000   0.8  0.869565
# 2      0.727273   0.4  1.000000
# 3      1.000000   0.4  0.913043
# 4      1.000000   0.6  1.000000
# ...         ...   ...       ...
# 38753  0.090909   0.4  0.652174
# 38754  1.000000   0.8  0.695652
# 38755  0.090909   0.2  0.869565
# 38756  0.272727   0.2  0.826087
# 38757  0.090909   0.2  0.826087
#
# [38758 rows x 25 columns]

# %%
# import joblib

# joblib.dump(scaler, 'app_ml/delay/scaler_model.pkl')
# print("Modèle enregistré sous le nom 'scaler_model.pkl'.")

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# X_train=scaled_df1
models = {
    'LinearRegression': LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'ElasticNet': ElasticNet(),
    'RandomForest': RandomForestRegressor(),
    'KNN': KNeighborsRegressor(),
    'GradientBoostingRegressor' : GradientBoostingRegressor()
}

# Define hyperparameters for GridSearchCV
param_grid = {
    'LinearRegression': {},
    'Lasso': {'regressor__alpha': [0.1, 1.0, 10.0]},  # prefix with 'regressor__' for model inside pipeline
    'Ridge': {'regressor__alpha': [0.1, 1.0, 10.0]},  # prefix with 'regressor__' for model inside pipeline
    'ElasticNet': {'regressor__alpha': [0.1, 1.0, 10.0], 'regressor__l1_ratio': [0.1, 0.5, 0.9]},
    'RandomForest': {'regressor__n_estimators': [50, 100, 200], 
                     'regressor__max_depth': [5, 10, None], 
                     'regressor__min_samples_split': [2, 5, 10]},
    'KNN': {'regressor__n_neighbors': [3, 5, 10], 
            'regressor__weights': ['uniform', 'distance'], 
            'regressor__p': [1, 2]} , # p=1 for Manhattan, p=2 for Euclidean distance
    'GradientBoostingRegressor': {
                                    'regressor__n_estimators': [100, 200, 300],
    'regressor__learning_rate': [0.01, 0.1, 0.2],
    'regressor__max_depth': [3, 5, 7],  # Correct usage of parameter with 'regressor__' prefix
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__subsample': [0.8, 1.0]
}
}

# Function to perform grid search for each model
best_models = {}

for name, model in models.items():
    # Create a pipeline without scaling, since the data is already scaled
    pipeline = Pipeline([
        ('regressor', model)  # Name the model step as 'regressor'
    ])
    
    # Setup GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid[name], cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    # Store the best model for each algorithm
    best_models[name] = grid_search.best_estimator_

# Now, you can compare the models' performance on the test set:
for name, model in best_models.items():
    score = model.score(X_test, y_test)
    print(f"{name} - R² score on test data: {score:.4f}")
    rmse = np.sqrt(mean_squared_error(y_test, model.predict(X_test)))
    print(f"{name} - RMSE score on test data: {rmse:.4f}")
# Out:
# C:\Users\omarr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# RandomForest - R² score on test data: 0.9652
# RandomForest - RMSE score on test data: 0.0654
# KNN - R² score on test data: 0.7754
# KNN - RMSE score on test data: 0.1662
# GradientBoostingRegressor - R² score on test data: 0.9649
# GradientBoostingRegressor - RMSE score on test data: 0.0657

# %%
best_models
# Out:
# {'RandomForest': Pipeline(steps=[('regressor', RandomForestRegressor())]),
#  'KNN': Pipeline(steps=[('regressor', KNeighborsRegressor(p=1, weights='distance'))]),
#  'GradientBoostingRegressor': Pipeline(steps=[('regressor',
#                   GradientBoostingRegressor(learning_rate=0.2, max_depth=7,
#                                             n_estimators=300, subsample=0.8))])}

# %%
# XGB = GradientBoostingRegressor(learning_rate=0.2 , max_depth=7,min_samples_split=10,n_estimators=300)
# XGB.fit(X_train,y_train)

# %%
# score = XGB.score(X_test, y_test)
# print(f"- R² score on test data: {score:.4f}")
# rmse = np.sqrt(mean_squared_error(y_test, XGB.predict(X_test)))
# print(f"- RMSE score on test data: {rmse:.4f}")

# %%
# test = XGB.predict(X_test)

# %%
# y_test

# %%
# test

# %%
# import joblib

# # Sauvegarder le modèle
# joblib.dump(XGB, 'xgb_noscaling_with_featuredump_25.pkl')
# print("Modèle enregistré sous le nom 'random_forest_model.pkl'.")

# %%
# df1["year"] =  pd.to_datetime( df1.datatime).dt.year
# df1["month"] = pd.to_datetime( df1.datatime).dt.month
# df1["dayofweek"] = pd.to_datetime( df1.datatime).dt.dayofweek
# df1["is_weekend"] = df1["dayofweek"].apply(lambda x: 1 if x >= 5 else 0)

# %%
# train_size = int(len(df1) * 0.8)
# train, test = df1.iloc[:train_size], df1.iloc[train_size:]

# %%
# from statsmodels.tsa.arima.model import ARIMA

# model = ARIMA(train["hypotension"], order=(5,1,0))  # AR(5), Diff(1), MA(0)
# model_fit = model.fit()
# forecast = model_fit.forecast(steps=len(test))

# %%
# prediction = model_fit.predict(steps=len(test)) 
# print(prediction)

# %%
# from prophet import Prophet

# df_prophet = df.reset_index().rename(columns={"date": "ds", "valeur": "y"})
# model = Prophet()
# model.fit(df_prophet)
# future = model.make_future_dataframe(periods=30)
# forecast = model.predict(future)

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense

# model = Sequential([
#     LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
#     LSTM(50),
#     Dense(1)
# ])
# model.compile(optimizer='adam', loss='mse')
